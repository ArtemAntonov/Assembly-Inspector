# %%
from src.d01_utils import Utils

# %%
Utils.extract_images('./data/input/coins/train', './data/temp/coins')
# Out:
#    301 frames extracted from ./data/coins/train/assembly/2025-05-29 13.09.40.mp4
# 301 images total in ./temp/coins/assembly
#    281 frames extracted from ./data/coins/train/coin_1/2025-05-29 13.09.58.mp4
# 281 images total in ./temp/coins/coin_1
#    241 frames extracted from ./data/coins/train/coin_2/2025-05-29 13.10.11.mp4
# 241 images total in ./temp/coins/coin_2
#    238 frames extracted from ./data/coins/train/coin_3/2025-05-29 13.10.25.mp4
# 238 images total in ./temp/coins/coin_3

# %%
Utils.extract_images('./data/input/screwdriver/train', './data/temp/screwdriver')
# Out:
#    532 frames extracted from ./data/screwdriver/train/assembly/2025-05-29 13.00.16.mp4
#    479 frames extracted from ./data/screwdriver/train/assembly/2025-05-29 13.00.52.mp4
#    543 frames extracted from ./data/screwdriver/train/assembly/2025-05-29 13.01.24.mp4
# 1554 images total in ./temp/screwdriver/assembly
#    431 frames extracted from ./data/screwdriver/train/bit/2025-05-29 13.02.33.mp4
# 431 images total in ./temp/screwdriver/bit
#    399 frames extracted from ./data/screwdriver/train/holder/2025-05-29 13.02.02.mp4
# 399 images total in ./temp/screwdriver/holder
#    548 frames extracted from ./data/screwdriver/train/screwdriver/2025-05-29 13.03.10.mp4
#    401 frames extracted from ./data/screwdriver/train/screwdriver/2025-05-29 13.03.30.mp4
# 949 images total in ./temp/screwdriver/screwdriver

# %%
Utils.extract_images('./data/input/puzzle/train', './data/temp/puzzle')
# Out:
#    415 frames extracted from ./data/puzzle/train/assembly/2025-05-29 17.19.03.mp4
# 415 images total in ./temp/puzzle/scale_1/assembly
#    368 frames extracted from ./data/puzzle/train/segment_1/2025-05-29 17.19.38.mp4
# 368 images total in ./temp/puzzle/scale_1/segment_1
#    439 frames extracted from ./data/puzzle/train/segment_2/2025-05-29 17.20.40.mp4
# 439 images total in ./temp/puzzle/scale_1/segment_2

# %%
Utils.extract_images('./data/input/wheels/five/train', './data/temp/wheels_five')
# Out:
#    357 frames extracted from ./data/wheels/five/train/assembly/2025-05-29 13.48.33.mp4
# 357 images total in ./temp/wheels_five/assembly
#    297 frames extracted from ./data/wheels/five/train/base/2025-05-29 13.22.28.mp4
# 297 images total in ./temp/wheels_five/base
#    279 frames extracted from ./data/wheels/five/train/black/2025-05-29 13.22.09.mp4
# 279 images total in ./temp/wheels_five/black
#    299 frames extracted from ./data/wheels/five/train/red/2025-05-29 13.21.38.mp4
# 299 images total in ./temp/wheels_five/red
#    319 frames extracted from ./data/wheels/five/train/screw/2025-05-29 13.23.42.mp4
# 319 images total in ./temp/wheels_five/screw
#    339 frames extracted from ./data/wheels/five/train/silver/2025-05-29 13.21.19.mp4
# 339 images total in ./temp/wheels_five/silver
#    256 frames extracted from ./data/wheels/five/train/white/2025-05-29 13.21.54.mp4
# 256 images total in ./temp/wheels_five/white
# ...

# %%
Utils.extract_images('./data/input/wheels/three/train', './data/temp/wheels_three')
# Out:
#    320 frames extracted from ./data/wheels/three/train/assembly/2025-05-29 13.41.59.mp4
# 320 images total in ./temp/wheels_three/assembly
#    297 frames extracted from ./data/wheels/three/train/base/2025-05-29 13.22.28.mp4
# 297 images total in ./temp/wheels_three/base
#    286 frames extracted from ./data/wheels/three/train/gray/2025-05-29 13.18.45.mp4
# 286 images total in ./temp/wheels_three/gray
#    319 frames extracted from ./data/wheels/three/train/screw/2025-05-29 13.23.42.mp4
# 319 images total in ./temp/wheels_three/screw
#    379 frames extracted from ./data/wheels/three/train/yellow/2025-05-30 11.26.48.mp4
# 379 images total in ./temp/wheels_three/yellow

# %%
Utils.extract_images('./data/input/wheels/two/train', './data/temp/wheels_two')
# Out:
#    312 frames extracted from ./data/wheels/two/train/assembly/2025-05-30 10.52.44.mp4
# 312 images total in ./temp/wheels_two/assembly
#    297 frames extracted from ./data/wheels/two/train/base/2025-05-29 13.22.28.mp4
# 297 images total in ./temp/wheels_two/base
#    319 frames extracted from ./data/wheels/two/train/screw/2025-05-29 13.23.42.mp4
# 319 images total in ./temp/wheels_two/screw
#    379 frames extracted from ./data/wheels/two/train/yellow/2025-05-30 11.26.48.mp4
# 379 images total in ./temp/wheels_two/yellow
#    327 frames extracted from ./data/wheels/two/train/yellow_marked/2025-05-29 13.18.24.mp4
# 327 images total in ./temp/wheels_two/yellow_marked

# %%
Utils.show_altered_image('./data/temp/coins/scale_1/assembly/0.jpg', .2, True)
# Out:
# Image size: 384:216
# <PIL.Image.Image image mode=RGB size=384x216>

# %%
Utils.alter_images('./data/temp/coins', .2, True)
# Out:
# Images with scale 0.2 created

# %%
Utils.show_altered_image('./data/temp/puzzle/scale_1/assembly/0.jpg', .15, True)
# Out:
# Image size: 288:162
# <PIL.Image.Image image mode=RGB size=288x162>

# %%
Utils.alter_images('./data/temp/puzzle', .15, True)
# Out:
# Images with scale 0.15 created

# %%
Utils.show_altered_image('./data/temp/screwdriver/scale_1/assembly/0.jpg', .35, True)
# Out:
# Image size: 672:378
# <PIL.Image.Image image mode=RGB size=672x378>

# %%
Utils.alter_images('./data/temp/screwdriver', .35, True)
# Out:
# Images with scale 0.35 created

# %%
Utils.show_altered_image('./data/temp/wheels_five/scale_1/assembly/0.jpg', .2, False)
# Out:
# Image size: 384:216
# <PIL.Image.Image image mode=RGB size=384x216>

# %%
Utils.alter_images('./data/temp/wheels_five', .2, False)
# Out:
# Images with scale 0.2 created

# %%
Utils.show_altered_image('./data/temp/wheels_three/scale_1/assembly/0.jpg', .15, False)
# Out:
# Image size: 288:162
# <PIL.Image.Image image mode=RGB size=288x162>
